# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("train.csv")
n = dataset.shape[0]
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataset["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dataset['Sex'] = dataset['Sex'].replace(to_replace = {'male': 1, 'female': 0})
dataset['Embarked'] = dataset['Embarked'].replace(to_replace = {'S': 1, 'C': 2, 'Q': 3})

# %%
dataset.hist(figsize  = (20, 25),layout= (dataset.columns.size//2,2), bins = 20)#floor division
plt.show()

# %%
dataset['Age'] = dataset['Age'].fillna(dataset['Age'].mean())

# %%
def normalization(data):
    data_range = data.max() - data.min()
    avg = data.mean()
    data = (data - avg) / data_range
    return data

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.647587   29.699118
# std     257.353842    0.486592    0.836071    0.477990   13.002015
# min       1.000000    0.000000    1.000000    0.000000    0.420000
# 25%     223.500000    0.000000    2.000000    0.000000   22.000000
# 50%     446.000000    0.000000    3.000000    1.000000   29.699118
# 75%     668.500000    1.000000    3.000000    1.000000   35.000000
# max     891.000000    1.000000    3.000000    1.000000   80.000000
#
#             SibSp       Parch        Fare    Embarked
# count  891.000000  891.000000  891.000000  889.000000
# mean     0.523008    0.381594   32.204208    1.362205
# std      1.102743    0.806057   49.693429    0.636157
# min      0.000000    0.000000    0.000000    1.000000
# 25%      0.000000    0.000000    7.910400    1.000000
# ...

# %%
frequent_data = dataset['Embarked'].value_counts().idxmax()
dataset['Embarked'] = dataset['Embarked'].fillna(frequent_data)
dataset['Embarked'].count()
# Out:
# 891

# %%
temp = dataset.columns.tolist()
input_col = np.setdiff1d(temp, ['Survived'])
output_col = np.setdiff1d(temp, input_col)
#input_col = np.setdiff1d(temp, ['Survived','Cabin', 'Name', ''])
input_col = np.setdiff1d(temp, ['Name', 'Ticket', 'Cabin', 'PassengerId', 'Survived'])#['Age', 'Embarked', 'Sex']
input_data = dataset[input_col]
input_data
# Out:
#            Age  Embarked     Fare  Parch  Pclass  Sex  SibSp
# 0    22.000000       1.0   7.2500      0       3    1      1
# 1    38.000000       2.0  71.2833      0       1    0      1
# 2    26.000000       1.0   7.9250      0       3    0      0
# 3    35.000000       1.0  53.1000      0       1    0      1
# 4    35.000000       1.0   8.0500      0       3    1      0
# ..         ...       ...      ...    ...     ...  ...    ...
# 886  27.000000       1.0  13.0000      0       2    1      0
# 887  19.000000       1.0  30.0000      0       1    0      0
# 888  29.699118       1.0  23.4500      2       3    0      1
# 889  26.000000       2.0  30.0000      0       1    1      0
# 890  32.000000       3.0   7.7500      0       3    1      0
#
# [891 rows x 7 columns]

# %%
output_data = dataset[output_col]
output_data
# Out:
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]

# %%
dataset['Age'] = normalization(dataset['Age'])

# %%
sex = dataset["Sex"].to_numpy().reshape(1,n)
age = dataset["Age"].to_numpy().reshape(1,n)
embark = dataset["Embarked"].to_numpy().reshape(1,n)
fare = dataset["Fare"].to_numpy().reshape(1,n)
y = dataset["Survived"].to_numpy().reshape(1,n)

# %%
normalization(input_data)
# Out:
#               Age  Embarked      Fare     Parch    Pclass       Sex     SibSp
# 0   -9.674689e-02 -0.180696 -0.048707 -0.063599  0.345679  0.352413  0.059624
# 1    1.043086e-01  0.319304  0.076277 -0.063599 -0.654321 -0.647587  0.059624
# 2   -4.648301e-02 -0.180696 -0.047390 -0.063599  0.345679 -0.647587 -0.065376
# 3    6.661074e-02 -0.180696  0.040786 -0.063599 -0.654321 -0.647587  0.059624
# 4    6.661074e-02 -0.180696 -0.047146 -0.063599  0.345679  0.352413 -0.065376
# ..            ...       ...       ...       ...       ...       ...       ...
# 886 -3.391704e-02 -0.180696 -0.037484 -0.063599 -0.154321  0.352413 -0.065376
# 887 -1.344448e-01 -0.180696 -0.004302 -0.063599 -0.654321 -0.647587 -0.065376
# 888  7.142928e-16 -0.180696 -0.017087  0.269734  0.345679 -0.647587  0.059624
# 889 -4.648301e-02  0.319304 -0.004302 -0.063599 -0.654321  0.352413 -0.065376
# 890  2.891282e-02  0.819304 -0.047731 -0.063599  0.345679  0.352413 -0.065376
#
# [891 rows x 7 columns]
